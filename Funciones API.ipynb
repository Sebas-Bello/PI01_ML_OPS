# %% [markdown]
# ### **Funciones API**

# %%
import pandas as pd
import numpy as np
import ast

# %%
data = pd.read_csv('Dataset\\Data_Clean_steam_games.csv',index_col=0)

# %%
data
# Out:
#                                                   genres
# 0      ['Action', 'Casual', 'Indie', 'Simulation', 'S...  \
# 1                      ['Action', 'Adventure', 'Casual']
# 2                  ['Action', 'Adventure', 'Simulation']
# 3      ['Free to Play', 'Indie', 'Simulation', 'Sports']
# 4      ['Free to Play', 'Indie', 'Simulation', 'Sports']
# ...                                                  ...
# 27232         ['Action', 'Adventure', 'Casual', 'Indie']
# 27233      ['Casual', 'Indie', 'Simulation', 'Strategy']
# 27234                    ['Casual', 'Indie', 'Strategy']
# 27235                  ['Indie', 'Racing', 'Simulation']
# 27236                                ['Casual', 'Indie']
#
#                            app_name
# 0               Lost Summoner Kitty  \
# 1                           弹炸人2222
# 2             Battle Royale Trainer
# 3      SNOW - All Access Basic Pass
# 4        SNOW - All Access Pro Pass
# ...                             ...
# 27232                  Kebab it Up!
# 27233                Colony On Mars
# 27234      LOGistICAL: South Africa
# 27235                 Russian Roads
# 27236           EXIT 2 - Directions
#
#                                                    specs  price  early_access
# 0                                      ['Single-player']   4.99         False  \
# 1                                      ['Single-player']   0.99         False
# 2                ['Single-player', 'Steam Achievements']   3.99         False
# 3      ['Single-player', 'Multi-player', 'Online Mult...   9.99         False
# 4      ['Single-player', 'Multi-player', 'Online Mult...  18.99         False
# ...                                                  ...    ...           ...
# 27232  ['Single-player', 'Steam Achievements', 'Steam...   1.99         False
# 27233            ['Single-player', 'Steam Achievements']   1.99         False
# 27234  ['Single-player', 'Steam Achievements', 'Steam...   4.99         False
# 27235  ['Single-player', 'Steam Achievements', 'Steam...   1.99         False
# 27236  ['Single-player', 'Steam Achievements', 'Steam...   4.99         False
#
#              id sentiment  metascore  year_release
# 0      761140.0       NaN        NaN          2018
# 1      767400.0       NaN        NaN          2017
# 2      772540.0     Mixed        NaN          2018
# 3      774276.0       NaN        NaN          2018
# 4      774277.0       NaN        NaN          2018
# ...         ...       ...        ...           ...
# 27232  745400.0       NaN        NaN          2018
# 27233  773640.0       NaN        NaN          2018
# 27234  733530.0       NaN        NaN          2018
# 27235  610660.0       NaN        NaN          2018
# 27236  658870.0       NaN        NaN          2017
#
# [27237 rows x 9 columns]

# %% [markdown]
# ---

# %%
# Crea una copia del DataFrame
data_copy = data.copy()

for col in ['genres']:
    for val in ['[', ']', '\'']:
        data_copy[col] = data_copy[col].str.replace(val, '').astype(str)

# Ahora, asignamos los cambios nuevamente al DataFrame original
data.loc[:, ['genres']] = data_copy.loc[:, ['genres']]

# %%
data.loc[:, 'genres'] = data['genres'].str.lower()

# %%
# Crear un DataFrame con las columnas de géneros
'''genres_df = data['genres'].str.get_dummies(', ')'''
# Out:
# "genres_df = data['genres'].str.get_dummies(', ')"

# %%
'''# Concatenar el nuevo DataFrame con el original
data = pd.concat([data, genres_df], axis=1)

pd.set_option('display.max_columns', None)

# Mostrar las primeras filas del DataFrame resultante
data.head()'''
# Out:
# "# Concatenar el nuevo DataFrame con el original\ndata = pd.concat([data, genres_df], axis=1)\n\npd.set_option('display.max_columns', None)\n\n# Mostrar las primeras filas del DataFrame resultante\ndata.head()"

# %% [markdown]
# ---

# %%
# Crea una copia del DataFrame
data_copy = data.copy()

for col in ['specs']:
    for val in ['[', ']', '\'']:
        data_copy[col] = data_copy[col].str.replace(val, '').astype(str)

# Ahora, asignamos los cambios nuevamente al DataFrame original
data.loc[:, ['specs']] = data_copy.loc[:, ['specs']]

# %%
data.loc[:, 'specs'] = data['specs'].str.lower()

# %%
# Crear un DataFrame con las columnas de géneros
'''specs_df = data['specs'].str.get_dummies(', ')'''
# Out:
# "specs_df = data['specs'].str.get_dummies(', ')"

# %%
'''# Concatenar el nuevo DataFrame con el original
data = pd.concat([data, specs_df], axis=1)

pd.set_option('display.max_columns', None)

# Mostrar las primeras filas del DataFrame resultante
data.head()'''
# Out:
# "# Concatenar el nuevo DataFrame con el original\ndata = pd.concat([data, specs_df], axis=1)\n\npd.set_option('display.max_columns', None)\n\n# Mostrar las primeras filas del DataFrame resultante\ndata.head()"

# %%
data
# Out:
#                                             genres
# 0      action, casual, indie, simulation, strategy  \
# 1                        action, adventure, casual
# 2                    action, adventure, simulation
# 3          free to play, indie, simulation, sports
# 4          free to play, indie, simulation, sports
# ...                                            ...
# 27232             action, adventure, casual, indie
# 27233          casual, indie, simulation, strategy
# 27234                      casual, indie, strategy
# 27235                    indie, racing, simulation
# 27236                                casual, indie
#
#                            app_name
# 0               Lost Summoner Kitty  \
# 1                           弹炸人2222
# 2             Battle Royale Trainer
# 3      SNOW - All Access Basic Pass
# 4        SNOW - All Access Pro Pass
# ...                             ...
# 27232                  Kebab it Up!
# 27233                Colony On Mars
# 27234      LOGistICAL: South Africa
# 27235                 Russian Roads
# 27236           EXIT 2 - Directions
#
#                                                    specs  price  early_access
# 0                                          single-player   4.99         False  \
# 1                                          single-player   0.99         False
# 2                      single-player, steam achievements   3.99         False
# 3      single-player, multi-player, online multi-play...   9.99         False
# 4      single-player, multi-player, online multi-play...  18.99         False
# ...                                                  ...    ...           ...
# 27232     single-player, steam achievements, steam cloud   1.99         False
# 27233                  single-player, steam achievements   1.99         False
# 27234  single-player, steam achievements, steam cloud...   4.99         False
# 27235  single-player, steam achievements, steam tradi...   1.99         False
# 27236     single-player, steam achievements, steam cloud   4.99         False
#
#              id sentiment  metascore  year_release
# 0      761140.0       NaN        NaN          2018
# 1      767400.0       NaN        NaN          2017
# 2      772540.0     Mixed        NaN          2018
# 3      774276.0       NaN        NaN          2018
# 4      774277.0       NaN        NaN          2018
# ...         ...       ...        ...           ...
# 27232  745400.0       NaN        NaN          2018
# 27233  773640.0       NaN        NaN          2018
# 27234  733530.0       NaN        NaN          2018
# 27235  610660.0       NaN        NaN          2018
# 27236  658870.0       NaN        NaN          2017
#
# [27237 rows x 9 columns]

# %% [markdown]
# ---

# %% [markdown]
# API 1

# %%
def genero(Año: str):
    try:
        año_str = str(Año)  # Convertir a cadena
        if not año_str.isdigit():
            raise ValueError(f"El año '{año_str}' no es un valor numérico válido.")
        
        año_num = int(Año)
        
        # Filtrar el DataFrame para obtener solo las filas del año ingresado
        df_filtrado = data[data['year_release'] == año_num]

        # Contar los registros por género
        genres_counts = {}

        for genres_list in df_filtrado['genres']:
            genres = genres_list.split(', ')
            for genre in genres:
                if genre in genres_counts:
                    genres_counts[genre] += 1
                else:
                    genres_counts[genre] = 1

        # Ordenar y tomar los 5 géneros con más registros
        top_5_generos = dict(sorted(genres_counts.items(), key=lambda item: item[1], reverse=True)[:5])
        
        if not top_5_generos:
            return f"No hay géneros disponibles para el año {Año}"

        return {año_num: top_5_generos}
    except ValueError as e:
        opciones_disponibles = '\n'.join(map(str, sorted(data['year_release'].unique())))
        return  print(f"Error: {e}\nEl año '{Año}' no es válido. Años disponibles:\n{opciones_disponibles}")

# %%
genero(2010)
# Out:
# {2010: {'action': 143,
#   'indie': 105,
#   'strategy': 102,
#   'adventure': 84,
#   'casual': 70}}

# %% [markdown]
# API 2

# %%
def juegos(Año: str):
    try:
        año_str = str(Año)  # Convertir a cadena
        if not año_str.isdigit():
            raise ValueError(f"El año '{año_str}' no es un valor numérico válido.")
        
        año_num = int(Año)
        
        # Filtrar el DataFrame para obtener solo las filas del año ingresado
        df_filtrado = data[data['year_release'] == año_num]
        
        # Crear un diccionario para almacenar el nombre del juego y el año
        juegos_por_año = {}
        
        # Iterar sobre las filas filtradas y agregar el nombre del juego y el año al diccionario
        for index, row in df_filtrado.iterrows():
            juego = row['app_name']
            juegos_por_año[juego] = año_num
        
        if not juegos_por_año:
            return f"No hay juegos para el año {Año}"
        
        return juegos_por_año
    except ValueError as e:
        opciones_disponibles = '\n'.join(map(str, sorted(data['year_release'].unique())))
        return print(f"Error: {e}\nEl año '{Año}' no es válido. Años disponibles:\n{opciones_disponibles}")

# %%
juegos("2010")
# Out:
# {'Avencast: Rise of the Mage': 2010,
#  'Farm Frenzy 3: American Pie': 2010,
#  'Cake Mania Main Street™': 2010,
#  'Westward® IV: All Aboard': 2010,
#  'Iron Roses': 2010,
#  'UFO: Extraterrestrials Gold': 2010,
#  'LEGO® Indiana Jones™ 2: The Adventure Continues': 2010,
#  'Super Laser  Racer': 2010,
#  'Hearts of Iron III: Soviet Infantry Pack DLC': 2010,
#  'NecroVisioN: Lost Company': 2010,
#  'Aliens vs. Predator Swarm Map Pack': 2010,
#  'Train Simulator: Fort Kent to Eagle Lake Route Add-On': 2010,
#  'Mount & Blade: Warband': 2010,
#  'Coniclysm': 2010,
#  'Plain Sight': 2010,
#  'Lead and Gold: Gangs of the Wild West': 2010,
#  'Grand Theft Auto: Episodes from Liberty City': 2010,
#  'Dark Void™ Zero': 2010,
#  'Fortix': 2010,
#  'Beat Hazard': 2010,
#  'Sam & Max: The Devil’s Playhouse': 2010,
#  'M.U.D. TV': 2010,
#  'Wings of Luftwaffe Add-on': 2010,
#  'The Misadventures of P.B. Winterbottom': 2010,
#  'Fluttabyes': 2010,
#  'Napoleon: Total War™ - Coalition Battle Pack': 2010,
#  "Nightshift Legacy: The Jaguar's Eye™": 2010,
#  'Biozone': 2010,
#  'Rocket Knight': 2010,
#  'Flight of the Icarus': 2010,
#  'Puzzler World': 2010,
#  'Prince of Persia: The Forgotten Sands™ Digital Deluxe Edition': 2010,
#  'Ziro': 2010,
#  'Altered Beast™': 2010,
#  'Comix Zone™': 2010,
#  'SEGA Mega Drive and Genesis Classics': 2010,
#  'Golden Axe™': 2010,
#  'Ecco the Dolphin™': 2010,
#  'Gain Ground™': 2010,
#  'Shinobi™ III: Return of the Ninja Master': 2010,
#  'Crack Down™': 2010,
#  'VectorMan™': 2010,
#  'Sonic 3D Blast™': 2010,
#  'Shadow Dancer™': 2010,
#  'Space Harrier™ II': 2010,
#  'Alpha Protocol™': 2010,
#  'Alien Breed: Impact': 2010,
#  'Fallout 3 - Point Lookout': 2010,
#  'Defense Grid: Resurgence Map Pack 1': 2010,
#  'Fallout 3 - Mothership Zeta': 2010,
#  'Fallout 3 - Broken Steel': 2010,
#  'Fallout 3 - The Pitt': 2010,
#  'Fallout 3 - Operation Anchorage': 2010,
#  'Disciples III - Renaissance Steam Special Edition': 2010,
#  'Tidalis': 2010,
#  'Razor2: Hidden Skies': 2010,
#  'The Settlers 7: Uncharted Land Map Pack': 2010,
#  'Kane & Lynch 2: Dog Days': 2010,
#  'The Guild II Renaissance': 2010,
#  'Hearts of Iron III DLC: German II Spritepack': 2010,
#  'Trainz Simulator DLC: Blue Comet': 2010,
#  'Fantasy Wars': 2010,
#  'Train Simulator: Network Southeast Class 47 Loco Add-On': 2010,
#  'Puzzle Quest 2': 2010,
#  'Burn Zombie Burn!': 2010,
#  'Madballs B*D*I Clan Skins': 2010,
#  'Madballs Scorched Evolution Skin Rollup': 2010,
#  'Madballs BDI Evolution Skin Rollup': 2010,
#  'Madballs Holiday Skin Rollup': 2010,
#  'Victoria I Complete': 2010,
#  'Ship Simulator Extremes': 2010,
#  'Worms Reloaded': 2010,
#  'Making History II: The War of the World': 2010,
#  'Arma 2: British Armed Forces': 2010,
#  'Victoria II': 2010,
#  'Madballs Scorched Clan Skins': 2010,
#  'Kane & Lynch 2: The Doggie Bag': 2010,
#  'Kane & Lynch 2: Multiplayer Masks Pack': 2010,
#  'Trainz: Classic Cabon City': 2010,
#  'Kane & Lynch 2: Alliance Weapon Pack': 2010,
#  "Broken Sword: Director's Cut": 2010,
#  'Chime': 2010,
#  "Mafia II DLC: Jimmy's Vendetta": 2010,
#  'Sniper: Ghost Warrior - Map Pack': 2010,
#  'VVVVVV': 2010,
#  'The Settlers 7: Conquest - The Empire Expansion DLC': 2010,
#  'Amnesia: The Dark Descent': 2010,
#  "Recettear: An Item Shop's Tale": 2010,
#  'Swarm Arena': 2010,
#  'Super Thunder Blade™': 2010,
#  'Galaxy Force II™': 2010,
#  'Hacker Evolution': 2010,
#  'Hacker Evolution: Untold': 2010,
#  'Faerie Solitaire': 2010,
#  'Patrician IV - Steam Special Edition': 2010,
#  'Bonanza Bros.™': 2010,
#  "King's Bounty: Crossworlds": 2010,
#  'Train Simulator: Green & Gold HST DMU Add-On': 2010,
#  "Sid Meier's Civilization® V": 2010,
#  'Commander: Conquest of the Americas - Colonial Navy': 2010,
#  'Star Ruler': 2010,
#  'Blade Kitten': 2010,
#  'Alien Breed 2: Assault': 2010,
#  'Darksiders™': 2010,
#  "The Kings' Crusade": 2010,
#  "Age of Wonders II: The Wizard's Throne": 2010,
#  'Governor of Poker 2': 2010,
#  'Governor of Poker 2 - Premium Edition': 2010,
#  'Age of Wonders Shadow Magic': 2010,
#  'Age of Wonders': 2010,
#  'Medal of Honor™': 2010,
#  'Grotesque Tactics: Evil Heroes': 2010,
#  'Lost Planet® 2': 2010,
#  'Doc Clock: The Toasted Sandwich of Time': 2010,
#  'Fallout: New Vegas': 2010,
#  'The Polynomial - Space of the music': 2010,
#  'Puzzle Bots': 2010,
#  'Nimbus': 2010,
#  'Civilization V - Babylon (Nebuchadnezzar II)': 2010,
#  'DeathSpank': 2010,
#  'Virtua Fighter™ 2': 2010,
#  'Columns™ III': 2010,
#  'Sword of Vermilion™': 2010,
#  'Golden Axe™ II': 2010,
#  'Sonic The Hedgehog': 2010,
#  'Flicky™': 2010,
#  'ESWAT™: City Under Siege': 2010,
#  'Ecco™: The Tides of Time': 2010,
#  'Decap Attack™': 2010,
#  'Bio-Hazard Battle™': 2010,
#  'Alien Storm': 2010,
#  'Shank': 2010,
#  'The Ball': 2010,
#  'STAR WARS™: The Force Unleashed™ II': 2010,
#  'Flight Control HD': 2010,
#  'Patrician III': 2010,
#  'BIT.TRIP BEAT': 2010,
#  'Theatre of War 2 - Battle for Caen': 2010,
#  'Woody Two-Legs: Attack of the Zombie Pirates': 2010,
#  'Clones': 2010,
#  'Victoria II: Interwar Spritepack': 2010,
#  'Front Mission Evolved: Wanzer Pack 2': 2010,
#  'Pound of Ground': 2010,
#  'Alternativa': 2010,
#  'Archon Classic': 2010,
#  'Call of Duty®: Black Ops': 2010,
#  'Rhythm Zone Tornado Visualizer DLC': 2010,
#  'Arcadia': 2010,
#  "Oddworld: Munch's Oddysee": 2010,
#  'Rhythm Zone DJ Table Visualizer DLC': 2010,
#  "Oddworld: Stranger's Wrath HD": 2010,
#  'Clickr': 2010,
#  'Back to the Future: The Game': 2010,
#  'The Sims™ 3 Fast Lane Stuff': 2010,
#  'The Sims™ 3 Late Night': 2010,
#  'The Sims™ 3 Ambitions': 2010,
#  'The Sims™ 3 High-End Loft Stuff': 2010,
#  'Armada 2526': 2010,
#  'Nancy Drew®: Secrets Can Kill REMASTERED': 2010,
#  'Nancy Drew®: Trail of the Twister': 2010,
#  "Nancy Drew®: Shadow at the Water's Edge": 2010,
#  'Real Warfare 1242': 2010,
#  'Train Simulator: Glasgow Airport Rail Link Route Add-On': 2010,
#  'Serious Sam HD: The Second Encounter': 2010,
#  "Din's Curse": 2010,
#  'DCS: A-10C Warthog - DLC': 2010,
#  'Sentinel 3: Homeworld': 2010,
#  'Konung 3: Ties of the Dynasty': 2010,
#  'Battle Academy - Blitzkrieg France': 2010,
#  'Redneck Racers': 2010,
#  'Deadly Sin 2': 2010,
#  'Millionaire Manor': 2010,
#  'Flower Shop: Summer In Fairbrook': 2010,
#  'Wildlife Park 2 - Farm World': 2010,
#  'Disney•Pixar Toy Story Mania!': 2010,
#  "Disney•Pixar Cars Toon: Mater's Tall Tales": 2010,
#  'Darkness Within 2: The Dark Lineage': 2010,
#  '15 Days': 2010,
#  'Official Guide - Millennium 3': 2010,
#  'OASE - Other Age Second Encounter': 2010,
#  'Typing Instructor for Kids Platinum 5': 2010,
#  'Typing Instructor Platinum 21': 2010,
#  'JourneyQuest Season One': 2010,
#  'The Twilight Saga: Eclipse': 2010,
#  'The Twilight Saga: New Moon': 2010,
#  'The Expendables': 2010,
#  'Saw 6': 2010,
#  'Red': 2010,
#  'Apocalypse Now Redux': 2010,
#  'Planet Hulk': 2010,
#  'After Dark Horrorfest 4: The Graves': 2010,
#  'After Dark Horrorfest 4: Dread': 2010,
#  'Extract': 2010,
#  'Megapolis': 2010,
#  'More Than a Game': 2010,
#  'Loups=Garous': 2010,
#  'The Conversation': 2010,
#  'Hunting Unlimited 2011': 2010,
#  'Yu-Gi-Oh! Bonds Beyond Time': 2010,
#  'Academagia: The Making of Mages': 2010,
#  'Choice of Broadsides': 2010,
#  'Fireplace for your Home : Crackling Fireplace': 2010,
#  'Nurse Jackie': 2010,
#  'Neven': 2010,
#  'Kubix': 2010,
#  'Level Up': 2010,
#  'Blast': 2010,
#  '古剑奇谭(GuJian)': 2010,
#  'Aaron Karo: The Rest is History': 2010,
#  'Indian Comedy Tour': 2010,
#  'Jackie Chan Presents: Wushu': 2010,
#  'Typing Instructor Platinum 21 - Mac': 2010,
#  'Typing Instructor for Kids Platinum 5 - Mac': 2010,
#  'Colorful the Movie': 2010,
#  'Red vs. Blue: Revelation (Volume 8)': 2010,
#  'Red vs. Blue: Recreation (Volume 7)': 2010,
#  'Kisaragi no Hougyoku': 2010,
#  'Cabin Fever 2: Spring Fever': 2010,
#  'Bullet Life 2010': 2010,
#  'After Dark Horrorfest 4: Zombies of Mass Destruction': 2010,
#  'After Dark: The Reeds': 2010,
#  'After Dark Horrorfest 4: The Final': 2010,
#  'Daybreakers': 2010,
#  'Kick-Ass': 2010,
#  'Bleach The Movie: Hell Verse': 2010,
#  'Naruto Shippuden the Movie: The Lost Tower': 2010,
#  'Mytheon': 2010,
#  'Wildlife Camp': 2010,
#  'Gillespie': 2010,
#  'Get Rich or Die Gaming': 2010,
#  'The Oil Blue: Steam Legacy Edition': 2010,
#  "Gary Grigsby's War in the East": 2010,
#  "Al Emmo's Postcards from Anozira": 2010,
#  'Decisive Campaigns: The Blitzkrieg from Warsaw to Paris': 2010,
#  'Season Match 3 - Curse of the Witch Crow': 2010,
#  'Split/Second': 2010,
#  "Disney's Tangled": 2010,
#  'Disney TRON: Evolution': 2010,
#  'Disney Alice in Wonderland': 2010,
#  'Moorhuhn / Crazy Chicken Tales': 2010,
#  'Quake Live™': 2010,
#  'Date Warp': 2010,
#  'Empress Of The Deep': 2010,
#  'Hotel Collectors Edition': 2010,
#  'Escape The Lost Kingdom: The Forgotten Pharaoh': 2010,
#  'Battle Academy': 2010,
#  'US and THEM': 2010,
#  'Glacier 3: The Meltdown': 2010,
#  'Skyscraper Simulator': 2010,
#  'Sherlock Holmes and The Hound of The Baskervilles': 2010,
#  'PT Boats: South Gambit': 2010,
#  'Zombie Pirates': 2010,
#  'Swords and Soldiers HD': 2010,
#  'Battlefield Bad Company 2: SPECACT Kit Upgrade': 2010,
#  'Bejeweled® 3': 2010,
#  'RUSH': 2010,
#  'Greed Corp': 2010,
#  'Killing Floor "London\'s Finest" Character Pack': 2010,
#  'The Settlers 7: Downloadable Content Pack III': 2010,
#  'Blue Toad Murder Files™: The Mysteries of Little Riddle': 2010,
#  'Need For Speed: Hot Pursuit': 2010,
#  'Mafia II DLC: Betrayal of Jimmy': 2010,
#  'Train Simulator: Falmouth Branch Route Add-On': 2010,
#  'Civilization V - Civ and Scenario Double Pack: Spain and Inca': 2010,
#  'Battlefield: Bad Company 2 Vietnam': 2010,
#  'Winter Voices Episode 2: Nowhere of me': 2010,
#  'Farming Simulator 2011 Equipment Pack 1': 2010,
#  'Dive to the Titanic': 2010,
#  'Front Mission Evolved: Weapon Pack 2': 2010,
#  'The UnderGarden': 2010,
#  'Guardians of Graxia': 2010,
#  'Gratuitous Space Battles: The Nomads': 2010,
#  'Zen Bound 2': 2010,
#  'Front Mission Evolved: Wanzer Pack 3': 2010,
#  'Alien Breed 3: Descent': 2010,
#  'Winter Voices Episode 1: Those who have no name': 2010,
#  'Guardians of Graxia Map Pack': 2010,
#  'Poker Night at the Inventory': 2010,
#  "Mafia II DLC: Joe's Adventure": 2010,
#  'Front Mission Evolved: Last Stand': 2010,
#  'Front Mission Evolved: Map Pack': 2010,
#  'DeathSpank: Thongs of Virtue': 2010,
#  'MX vs. ATV Reflex': 2010,
#  'Super Meat Boy': 2010,
#  'Arma 2: Private Military Company': 2010,
#  'Civilization V - Cradle of Civilization Map Pack: Mediterranean': 2010,
#  'Civilization V - Cradle of Civilization Map Pack: Asia': 2010,
#  "nail'd": 2010,
#  'Civilization V - Cradle of Civilization Map Pack: Americas': 2010,
#  'Dragon Age: Origins - Ultimate Edition': 2010,
#  'Civilization V - Cradle of Civilization Map Pack: Mesopotamia': 2010,
#  'Grand Theft Auto IV: Complete Edition': 2010,
#  'AI War: Children of Neinzul': 2010,
#  'Tommy Tronic': 2010,
#  'Blood Bowl® Legendary Edition': 2010,
#  'Farming Simulator 2011': 2010,
#  'Bloody Good Time': 2010,
#  'Winter Voices': 2010,
#  'ArcaniA': 2010,
#  'Delve Deeper': 2010,
#  'Dead Rising® 2': 2010,
#  'NyxQuest: Kindred Spirits': 2010,
#  'Lost Horizon': 2010,
#  'Rhythm Zone:  Deep Ocean Visualizer': 2010,
#  'Supreme Commander 2: Infinite War Battle Pack': 2010,
#  'Mafia II DLC: Renegade Pack': 2010,
#  'Front Mission Evolved': 2010,
#  'Mafia II DLC: Greaser Pack': 2010,
#  'Mafia II DLC: Vegas Pack': 2010,
#  'Mafia II DLC: War Hero Pack': 2010,
#  'Lara Croft and the Guardian of Light': 2010,
#  "Borderlands: Claptrap's Robot Revolution": 2010,
#  'Haunted House™': 2010,
#  'Air Forte': 2010,
#  'Trainz Settle and Carlisle': 2010,
#  'Axel & Pixel': 2010,
#  'Killing Floor: PostMortem Character Pack': 2010,
#  'Diamond Dan': 2010,
#  'Rhythm Zone Mesh Visualizer DLC': 2010,
#  'Columns™': 2010,
#  'Rhythm Zone Revolution Visualizer DLC': 2010,
#  'Ristar™': 2010,
#  'Alex Kidd™ in the Enchanted Castle': 2010,
#  'Sonic Spinball™': 2010,
#  'Kid Chameleon™': 2010,
#  'Fatal Labyrinth™': 2010,
#  'Eternal Champions™': 2010,
#  'Ecco™ Jr.': 2010,
#  'Dr. Robotnik’s Mean Bean Machine™': 2010,
#  'Commander: Conquest of the Americas': 2010,
#  'Alter Ego': 2010,
#  'Power of Defense': 2010,
#  'Numen: Contest of Heroes': 2010,
#  'Hearts of Iron III: Semper Fi': 2010,
#  'eversion': 2010,
#  'Prince of Persia: The Forgotten Sands™': 2010,
#  'Jolly Rover': 2010,
#  'Defense Grid: Resurgence Map Pack 2': 2010,
#  'DogFighter': 2010,
#  'Spectromancer - League of Heroes': 2010,
#  'Napoleon: Total War™ - The Peninsular Campaign': 2010,
#  'Defense Grid: Resurgence Map Pack 3': 2010,
#  "Just Cause 2: Bull's Eye Assault Rifle": 2010,
#  "Just Cause 2: Rico's Signature Gun DLC": 2010,
#  'Just Cause 2: Agency Hovercraft': 2010,
#  'Just Cause 2: Chevalier Classic': 2010,
#  'Sniper: Ghost Warrior': 2010,
#  'Just Cause 2: Monster Truck DLC': 2010,
#  'Defense Grid: Resurgence Map Pack 4': 2010,
#  'Puzzle Dimension': 2010,
#  'Aliens vs Predator™ Bughunt Map Pack': 2010,
#  'King Arthur: The Saxons': 2010,
#  'Rig n Roll': 2010,
#  'Theatre of War 2: Kursk 1943': 2010,
#  'Reign: Conflict of Nations': 2010,
#  'Eschalon: Book II': 2010,
#  'Day of Defeat: Source': 2010,
#  'Blacklight: Tango Down': 2010,
#  'Future Wars': 2010,
#  'Voodoo Dice': 2010,
#  'LEGO Harry Potter: Years 1-4': 2010,
#  'Arma 2: Operation Arrowhead': 2010,
#  'Singularity™': 2010,
#  'Train Simulator: Fowler 4F Loco Add-On': 2010,
#  'Gratuitous Space Battles: The Swarm': 2010,
#  'Tropico 3: Absolute Power': 2010,
#  'Majesty 2: Kingmaker': 2010,
#  'Killing Floor: Nightfall Character Pack': 2010,
#  'Just Cause 2 - Black Market Boom Pack DLC': 2010,
#  "Tom Clancy's Splinter Cell Conviction Insurgency Pack": 2010,
#  'Beat Hazard – iTunes & m4a file support': 2010,
#  'Napoleon: Total War™': 2010,
#  'Gridrunner Revolution': 2010,
#  'Borderlands: The Secret Armory of General Knoxx': 2010,
#  'Arsenal of Democracy: A Hearts of Iron Game': 2010,
#  'Napoleon: Total War™ Imperial Edition': 2010,
#  'Battlefield: Bad Company™ 2': 2010,
#  'Supreme Commander 2': 2010,
#  'Star Wolves 3: Civil War': 2010,
#  'Star Wolves': 2010,
#  'Sonic & SEGA All-Stars Racing': 2010,
#  'Silent Hunter 5®: Battle of the Atlantic': 2010,
#  "Assassin's Creed 2 Deluxe Edition": 2010,
#  'Just Cause 2': 2010,
#  'Star Wolves 2': 2010,
#  'Warhammer® 40,000: Dawn of War® II Chaos Rising': 2010,
#  'Shatter': 2010,
#  'Gratuitous Space Battles: The Order': 2010,
#  'Dragon Age™: Origins Awakening': 2010,
#  'Command & Conquer 4: Tiberian Twilight': 2010,
#  'Dark Fall: Lost Souls': 2010,
#  'World Basketball Manager 2010': 2010,
#  'Hazen: The Dark Whispers': 2010,
#  'Booster Trooper': 2010,
#  "Tom Clancy's Splinter Cell Conviction™ Deluxe Edition": 2010,
#  'Just Cause 2: Black Market Aerial Pack DLC': 2010,
#  'Flotilla': 2010,
#  'Call of Duty®: Modern Warfare® 2 Stimulus Package': 2010,
#  'Sol Survivor': 2010,
#  "Borderlands: Mad Moxxi's Underdome Riot": 2010,
#  'Zero Gear': 2010,
#  'AI War: The Zenith Remnant': 2010,
#  'Greed: Black Border': 2010,
#  'Nancy Drew®: Warnings at Waverly Academy': 2010,
#  'Madballs Anarchy Unlock Pack': 2010,
#  'Dark Void™': 2010,
#  'King Arthur: Knights and Vassals DLC': 2010,
#  'King Arthur: Legendary Artifacts DLC': 2010,
#  'A.I.M. Racing': 2010,
#  'Bob Came in Pieces': 2010,
#  'Mass Effect 2': 2010,
#  'Hotel Giant 2': 2010,
#  'Grand Ages: Rome - Reign of Augustus': 2010,
#  'Mass Effect 2 Digital Deluxe Edition': 2010,
#  'Toki Tori': 2010,
#  'Secret of the Magic Crystals': 2010,
#  'Aliens vs. Predator™': 2010,
#  'Empire: Total War™ - Elite Units of the East': 2010,
#  'SEASON OF MYSTERY: The Cherry Blossom Murders': 2010,
#  'BioShock® 2': 2010,
#  'Lost Planet: Extreme Condition Colonies Edition': 2010,
#  'Mishap: An Accidental Haunting': 2010,
#  'S.T.A.L.K.E.R.: Call of Pripyat': 2010,
#  'The Otherside: Realm of Eons': 2010,
#  'Galcon Fusion': 2010,
#  'Nation Red': 2010,
#  'Batman: Arkham Asylum Game of the Year Edition': 2010}

# %% [markdown]
# API 3

# %%
def specs(Año: str):
    try:
        año_str = str(Año)  # Convertir a cadena
        if not año_str.isdigit():
            raise ValueError(f"El año '{año_str}' no es un valor numérico válido.")
        
        año_num = int(Año)
        
        # Filtrar el DataFrame para obtener solo las filas del año ingresado
        df_filtrado = data[data['year_release'] == año_num]

        # Contar los registros por género
        genres_counts = {}

        for genres_list in df_filtrado['specs']:
            genres = genres_list.split(', ')
            for genre in genres:
                if genre in genres_counts:
                    genres_counts[genre] += 1
                else:
                    genres_counts[genre] = 1

        # Ordenar y tomar los 5 géneros con más registros
        top_5_generos = dict(sorted(genres_counts.items(), key=lambda item: item[1], reverse=True)[:5])
        
        if not top_5_generos:
            return f"No hay géneros disponibles para el año {Año}"

        return {año_num: top_5_generos}
    except ValueError as e:
        opciones_disponibles = '\n'.join(map(str, sorted(data['year_release'].unique())))
        return  print(f"Error: {e}\nEl año '{Año}' no es válido. Años disponibles:\n{opciones_disponibles}")

# %%
specs("2010")
# Out:
# {2010: {'single-player': 359,
#   'steam achievements': 146,
#   'multi-player': 138,
#   'partial controller support': 125,
#   'downloadable content': 105}}

# %% [markdown]
# API 4

# %%
def earlyacces(Año: str):
    try:
        año_str = str(Año)  # Convertir a cadena
        if not año_str.isdigit():
            raise ValueError(f"El año '{año_str}' no es un valor numérico válido.")
        
        año_num = int(Año)
        
        # Filtrar el DataFrame para obtener solo las filas del año ingresado y que tengan early access True
        df_filtrado = data[(data['year_release'] == año_num) & (data['early_access'] == True)]
        
        # Contar la cantidad de juegos con early access True
        cantidad_early_access = df_filtrado.shape[0]
        
        if not cantidad_early_access:
            return {año_num: 0}
        
        return {año_num: cantidad_early_access}
    except ValueError as e:
        opciones_disponibles = '\n'.join(map(str, sorted(data['year_release'].unique())))
        return print(f"Error: {e}\nEl año '{Año}' no es válido. Años disponibles:\n{opciones_disponibles}")

# %%
earlyacces("2017")
# Out:
# {2017: 660}

# %% [markdown]
# API 5

# %%
def sentiment(Año: str):
    try:
        año_str = str(Año)  # Convertir a cadena
        if not año_str.isdigit():
            raise ValueError(f"El año '{año_str}' no es un valor numérico válido.")
        
        año_num = int(Año)
        
        # Filtrar el DataFrame para obtener solo las filas del año ingresado
        df_filtrado = data[data['year_release'] == año_num]
        
        # Contar la cantidad de registros para cada categoría de sentimiento
        conteo_sentimientos = df_filtrado['sentiment'].value_counts()
        
        # Convertir el diccionario de conteo_sentimientos en un diccionario
        diccionario_sentimientos = conteo_sentimientos.to_dict()
        
        if not diccionario_sentimientos:
            return f"No hay especificaciones disponibles para el año {Año}"
        
        return {año_num: diccionario_sentimientos}
    except ValueError as e:
        opciones_disponibles = '\n'.join(map(str, sorted(data['year_release'].unique())))
        return print(f"Error: {e}\nEl año '{Año}' no es válido. Años disponibles:\n{opciones_disponibles}")

# %%
sentiment("2011")
# Out:
# {2011: {'Very Positive': 119,
#   'Mixed': 82,
#   'Mostly Positive': 54,
#   'Positive': 49,
#   'Mostly Negative': 20,
#   'Overwhelmingly Positive': 12,
#   'Very Negative': 1,
#   'Overwhelmingly Negative': 1,
#   'Negative': 1}}

# %% [markdown]
# API 6

# %%
def metascore(Año: str):
    try:
        año_str = str(Año)  # Convertir a cadena
        if not año_str.isdigit():
            raise ValueError(f"El año '{año_str}' no es un valor numérico válido.")
        
        año_num = int(Año)
        
        # Filtrar el DataFrame para obtener solo las filas del año ingresado
        df_filtrado = data[data['year_release'] == año_num]
        
        # Ordenar los juegos según el puntaje Metascore en orden descendente
        top_juegos_metascore = df_filtrado.sort_values(by='metascore', ascending=False).head(5)
        
        # Convertir el DataFrame en un diccionario con el título del juego como clave y el Metascore como valor
        resultado = top_juegos_metascore.set_index('app_name')['metascore'].to_dict()
        
        if not resultado:
            return f"No hay especificaciones disponibles para el año {Año}"
        
        return {año_num: resultado}
    except ValueError as e:
        opciones_disponibles = '\n'.join(map(str, sorted(data['year_release'].unique())))
        return print(f"Error: {e}\nEl año '{Año}' no es válido. Años disponibles:\n{opciones_disponibles}")

# %%
metascore("2017")
# Out:
# {2017: {'Divinity: Original Sin 2': 93.0,
#   'OKAMI HD / 大神 絶景版': 93.0,
#   'Linelight': 90.0,
#   'Bayonetta': 90.0,
#   'F1™ 2017': 89.0}}
